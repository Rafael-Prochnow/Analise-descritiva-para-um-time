# %% [markdown]
# # Funções para criação do Relatório de Análises

# %% [markdown]
# # Cabeçalho

# %%
def cabecalho_rodape(pdf, arquivo):
    pdf.image(f'{arquivo}/Sem título 1.jpg', x=0, y=0, w=210)
    pdf.image(f'{arquivo}/Sem título 2.jpg', x=0, y=287, w=210)

# %% [markdown]
# # Capa

# %%
def criar_titulo(pdf, data):
    # Data de criação do relatório
    pdf.set_xy(160, 15)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=40, h=10, txt=f'Dia {data}', border=1, ln=1, align='C')
    # Título
    pdf.set_xy(10, 40)
    pdf.set_font('Times', 'B', 26)
    pdf.cell(190, h=30, txt= 'Relatório de Jogo', border=1, ln=1, align='C')

# %%
def fotos_dos_times(pdf, img_casa, nome_casa, img_fora, nome_fora):
    # Foto do time da casa
    pdf.image(f'{img_casa}.png', x=40, y=98, w=27, h=27)
    # Nome do time da casa
    pdf.set_xy(40, 126)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=26, h=10, txt= f'{nome_casa}', border=1, ln=1, align='C')
    # foto do time de Fora
    pdf.image(f'{img_fora}.png', x=138, y=98, w=27, h=27)
    # Nome do time da fora
    pdf.set_xy(138, 126)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=26, h=10, txt= f'{nome_fora}', border=1, ln=1, align='C')

# %%
def informacoes_do_placar(pdf, posicao, placar_casa, placar_fora, dia_jogo):
    # Informações da rodada 
    pdf.set_xy(83, 85)
    pdf.set_font('Times', 'B', 16)
    pdf.cell(w=40, h=10, txt= f'{posicao}', border=1, ln=1, align='C')
    # Colocar 'X'
    pdf.set_xy(100, 113)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=5, h=5, txt= 'X', border=1, ln=1, align='C')
    # Informações do Placar Casa
    pdf.set_xy(77, 105)
    pdf.set_font('Times', 'B', 32)
    pdf.set_text_color(255)
    pdf.set_fill_color(9, 89, 153)
    pdf.cell(w=20, h=20, txt= f'{placar_casa}', border=1, fill=True,ln=1, align='C')
    # Informações do Placar Fora
    pdf.set_xy(108, 105)
    pdf.set_font('Times', 'B', 32)
    pdf.set_text_color(255)
    pdf.set_fill_color(242, 168, 19)
    pdf.cell(w=20, h=20, txt= f'{placar_fora}', border=1, fill=True,ln=1, align='C')
    # Informação do dia de jogo
    pdf.set_xy(78, 130)
    pdf.set_font('Times', 'B', 12)
    pdf.set_text_color(0)
    pdf.cell(w=50, h=10, txt= f'Dia da Partida: {dia_jogo}', border=1, ln=1, align='C')

# %%
def grafico_quartos_normal(pdf, nome_casa, nome_fora):
    # caixa de texto 1
    pdf.set_xy(63, 160)
    pdf.set_font('Times', 'B', 26)
    pdf.cell(97, h=20, txt= '', border='T, B', ln=0, align='C')
    # caixa de texto 2
    pdf.set_xy(63, 170)
    pdf.set_font('Times', 'B', 26)
    pdf.cell(97, h=10, txt= '', border='T', ln=0, align='C')
    # Primeiro Quarto
    pdf.set_xy(66, 152)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=10, h=8, txt= 'Q1', border=1, ln=1, align='C')
    # Segundo Quarto
    pdf.set_xy(86, 152)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=10, h=8, txt= 'Q2', border=1, ln=1, align='C')
    # Terceiro Quarto
    pdf.set_xy(106, 152)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=10, h=8, txt= 'Q3', border=1, ln=1, align='C')
    # Quarto Quarto
    pdf.set_xy(126, 152)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=10, h=8, txt= 'Q4', border=1, ln=1, align='C')
    # Fim de Jogo
    pdf.set_xy(146, 152)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=14, h=8, txt= 'FINAL', border=1, ln=1, align='C')
    # Nome do time Casa 
    pdf.set_xy(31, 161)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=30, h=8, txt= f'{nome_casa}', border=1, ln=1, align='C')
    # Nome do time Fora
    pdf.set_xy(31, 171)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=30, h=8, txt= f'{nome_fora}', border=1, ln=1, align='C')

# %%
def placar_do_quarto1(pdf, inf_placar_casa, inf_placar_fora):
    # Placar do Time Casa no Primeiro Quarto 
    pdf.set_xy(67, 161)
    pdf.set_font('Times', 'B', 12)
    if inf_placar_casa[0] > inf_placar_fora[0]:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_casa[0]}', border=1, ln=1, align='C')
    elif inf_placar_casa[0] <= inf_placar_fora[0]:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_casa[0]}', border=1, ln=1, align='C')
    # Placar do Time Fora no Primeiro Quarto 
    pdf.set_xy(67, 171)
    pdf.set_font('Times', 'B', 12)
    if inf_placar_casa[0] >= inf_placar_fora[0]:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_fora[0]}', border=1, ln=1, align='C')
    elif inf_placar_casa[0] < inf_placar_fora[0]:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_fora[0]}', border=1, ln=1, align='C')
    pdf.set_text_color(0)

# %%
def placar_do_quarto2(pdf, inf_placar_casa, inf_placar_fora):
    # Placar do Time Casa no Segundo Quarto 
    pdf.set_xy(87, 161)
    pdf.set_font('Times', 'B', 12)
    if inf_placar_casa[1] > inf_placar_fora[1]:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_casa[1]}', border=1, ln=1, align='C')
    elif inf_placar_casa[1] < inf_placar_fora[1]:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_casa[1]}', border=1, ln=1, align='C')
    # Placar do Time Fora no Segundo Quarto 
    pdf.set_xy(87, 171)
    pdf.set_font('Times', 'B', 12)
    if inf_placar_casa[1] > inf_placar_fora[1]:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_fora[1]}', border=1, ln=1, align='C')
    elif inf_placar_casa[1] < inf_placar_fora[1]:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_fora[1]}', border=1, ln=1, align='C')
    pdf.set_text_color(0)

# %%
def placar_do_quarto3(pdf, inf_placar_casa, inf_placar_fora):
    # Placar do Time da Casa no Terceiro Quarto 
    pdf.set_xy(107, 161)
    pdf.set_font('Times', 'B', 12)
    if inf_placar_casa[2] > inf_placar_fora[2]:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_casa[2]}', border=1, ln=1, align='C')
    elif inf_placar_casa[2] <= inf_placar_fora[2]:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_casa[2]}', border=1, ln=1, align='C')
    # Placar do Time da Fora no Terceiro Quarto 
    pdf.set_xy(107, 171)
    pdf.set_font('Times', 'B', 12)
    if inf_placar_casa[2] >= inf_placar_fora[2]:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_fora[2]}', border=1, ln=1, align='C')
    elif inf_placar_casa[2] < inf_placar_fora[2]:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_fora[2]}', border=1, ln=1, align='C')
    pdf.set_text_color(0)

# %%
def placar_do_quarto4(pdf, inf_placar_casa, inf_placar_fora):
    # Placar do Time da Casa no Quarto Quarto 
    pdf.set_xy(127, 161)
    pdf.set_font('Times', 'B', 12)
    if inf_placar_casa[3] > inf_placar_fora[3]:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_casa[3]}', border=1, ln=1, align='C')
    elif inf_placar_casa[3] <= inf_placar_fora[3]:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_casa[3]}', border=1, ln=1, align='C')
    # Placar do Time da Fora no Quarto Quarto 
    pdf.set_xy(127, 171)
    pdf.set_font('Times', 'B', 12)
    if inf_placar_casa[3] >= inf_placar_fora[3]:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_fora[3]}', border=1, ln=1, align='C')
    elif inf_placar_casa[3] < inf_placar_fora[3]:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{inf_placar_fora[3]}', border=1, ln=1, align='C')
    pdf.set_text_color(0)

# %%
def placar_final(pdf, placar_casa, placar_fora):
    # Placar Final do Time da Casa
    pdf.set_xy(149, 161)
    pdf.set_font('Times', 'B', 12)
    if placar_casa > placar_fora:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{placar_casa}', border=1, ln=1, align='C')
    elif placar_casa <= placar_fora:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{placar_casa}', border=1, ln=1, align='C')
    # Placar Final do Time da Fora 
    pdf.set_xy(149, 171)
    pdf.set_font('Times', 'B', 12)
    if placar_casa >= placar_fora:
        pdf.set_text_color(0)
        pdf.cell(w=8, h=8, txt= f'{placar_fora}', border=1, ln=1, align='C')
    elif placar_casa < placar_fora:
        pdf.set_text_color(220, 50, 50)
        pdf.cell(w=8, h=8, txt= f'{placar_fora}', border=1, ln=1, align='C')
    pdf.set_text_color(0)

# %%
def informacoes_do_relatorio(pdf):
    pdf.set_text_color(0)
    # onde posso escrever
    pdf.set_y(220)
    pdf.set_font('Times', 'B', 26)
    pdf.cell(190, h=30, txt= '', border=1, ln=1, align='C')

# %% [markdown]
# # Primeira página

# %%
def evolução_do_placar(pdf, arquivo):
    pdf.set_text_color(0)
    pdf.image(f'{arquivo}/teste.jpeg', x=55, y=25, w=130, h=65)

# %%
def comentarios_p1(pdf):
    pdf.set_text_color(0)
    # Título
    pdf.set_xy(10, 95)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=70, h=10, txt= 'Estátisticas Descritivas Comparativas', border=1, ln=1)
    # Comentários
    pdf.set_xy(10, 105)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(190, h=25, txt= '', border=1, ln=0, align='C')

# %%
def graficos_analise_descrivita_c1(pdf, valores, arquivo):
    pdf.set_text_color(0)
    wt = 57
    ht = 33 
    # Três Pontos Convertidos
    h1 = 136
    pdf.image(f'{arquivo}/Pts_3_C.png', x=10, y=h1, w=wt, h=ht)
    # Valor dos Três Pontos Convertidos 
    pdf.set_xy(62, h1+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_3_C[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(62, h1+19)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_3_C[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Três Pontos Tentados
    h2 = 172
    pdf.image(f'{arquivo}/Pts_3_T.png', x=10, y=h2, w=wt, h=ht)
    # Valor dos Três Pontos Tentados 
    pdf.set_xy(62, h2+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_3_T[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(62, h2+19)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_3_T[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Assistências
    h3 = 210
    pdf.image(f'{arquivo}/AS.png', x=10, y=h3, w=wt, h=ht)
    # Valor das Assistências
    pdf.set_xy(62, h3+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.AS[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(62, h3+19)
    pdf.cell(w=8, h=7, txt= f'{valores.AS[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Rebotes Ofensivos
    h4 = 248
    pdf.image(f'{arquivo}/RO.png', x=10, y=h4, w=wt, h=ht)
    # Valor dos Rebotes Ofensivos
    pdf.set_xy(62, h4+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.RO[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(62, h4+19)
    pdf.cell(w=8, h=7, txt= f'{valores.RO[1]}', border=1, ln=0, align='C')

# %%
def graficos_analise_descrivita_c2(pdf, valores, arquivo):
    pdf.set_text_color(0)
    wt = 57
    ht = 33 
    # Dois Pontos Convertidos
    h1 = 136
    pdf.image(f'{arquivo}/Pts_2_C.png', x=76, y=h1, w=wt, h=ht)
    # Valor dos Dois Pontos Convertidos
    pdf.set_xy(128, h1+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_2_C[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(128, h1+19)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_2_C[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Dois Pontos Tentados
    h2 = 172
    pdf.image(f'{arquivo}/Pts_2_T.png', x=76, y=h2, w=wt, h=ht)
    # Valor dos Dois Pontos Tentandos 
    pdf.set_xy(128, h2+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_2_T[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(128, h2+19)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_2_T[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Bolas Roubadas
    h3 = 210
    pdf.image(f'{arquivo}/BR.png', x=76, y=h3, w=wt, h=ht)
    # Valor das Bolas Roubadas
    pdf.set_xy(128, h3+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.BR[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(128, h3+19)
    pdf.cell(w=8, h=7, txt= f'{valores.BR[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Rebotes Defensivos
    h4 = 248
    pdf.image(f'{arquivo}/RD.png', x=76, y=h4, w=wt, h=ht)
    # Valor dos Rebotes Defensivos
    pdf.set_xy(128, h4+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.RD[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(128, h4+19)
    pdf.cell(w=8, h=7, txt= f'{valores.RD[1]}', border=1, ln=0, align='C')

# %%
def graficos_analise_descrivita_c3(pdf, valores, arquivo):
    pdf.set_text_color(0)
    wt = 57
    ht = 33 
    # Lances Livres Convertidos
    h1 = 136
    pdf.image(f'{arquivo}/LL_C.png', x=141, y=h1, w=wt, h=ht)
    # Valor dos Lances Livres Convertidos
    pdf.set_xy(192, h1+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.LL_C[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(192, h1+19)
    pdf.cell(w=8, h=7, txt= f'{valores.LL_C[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Lances Livres Tentados
    h2 = 172
    pdf.image(f'{arquivo}/LL_T.png', x=141, y=h2, w=wt, h=ht)
    # Valor dos Lances Livres Tentandos 
    pdf.set_xy(192, h2+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.LL_T[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(192, h2+19)
    pdf.cell(w=8, h=7, txt= f'{valores.LL_T[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Erros
    h3 = 210
    pdf.image(f'{arquivo}/ER.png', x=141, y=h3, w=wt, h=ht)
    # Valor dos Erros
    pdf.set_xy(192, h3+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.ER[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(192, h3+19)
    pdf.cell(w=8, h=7, txt= f'{valores.ER[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Rebotes Totais
    h4 = 248
    pdf.image(f'{arquivo}/RT.png', x=141, y=h4, w=wt, h=ht)
    # Valor dos Rebotes Totais
    pdf.set_xy(192, h4+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.RT[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(192, h4+19)
    pdf.cell(w=8, h=7, txt= f'{valores.RT[1]}', border=1, ln=0, align='C')

# %% [markdown]
# # Segunda Página

# %%
def comentarios_p2(pdf):
    pdf.set_text_color(0)
    # Título
    pdf.set_xy(10, 20)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=70, h=10, txt= 'Estátisticas Avançadas Comparativas', border=1, ln=1)
    # Comentários
    pdf.set_xy(10, 30)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(190, h=25, txt= '', border=1, ln=0, align='C')

# %%
def graficos_analise_avancadas_c1(pdf, valores, arquivo):
    pdf.set_text_color(0)
    wt = 57
    ht = 33 
    # Três Pontos Convertidos
    h1 = 60
    pdf.image(f'{arquivo}/Pts_3_C.png', x=10, y=h1, w=wt, h=ht)
    # Valor dos Três Pontos Convertidos 
    pdf.set_xy(62, h1+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_3_C[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(62, h1+19)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_3_C[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Três Pontos Tentados
    h2 = 96
    pdf.image(f'{arquivo}/Pts_3_T.png', x=10, y=h2, w=wt, h=ht)
    # Valor dos Três Pontos Tentados 
    pdf.set_xy(62, h2+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_3_T[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(62, h2+19)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_3_T[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Assistências
    h3 = 134
    pdf.image(f'{arquivo}/AS.png', x=10, y=h3, w=wt, h=ht)
    # Valor das Assistências
    pdf.set_xy(62, h3+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.AS[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(62, h3+19)
    pdf.cell(w=8, h=7, txt= f'{valores.AS[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Rebotes Ofensivos
    h4 = 172
    pdf.image(f'{arquivo}/RO.png', x=10, y=h4, w=wt, h=ht)
    # Valor dos Rebotes Ofensivos
    pdf.set_xy(62, h4+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.RO[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(62, h4+19)
    pdf.cell(w=8, h=7, txt= f'{valores.RO[1]}', border=1, ln=0, align='C')

# %%
def graficos_analise_avancadas_c2(pdf, valores, arquivo):
    pdf.set_text_color(0)
    wt = 57
    ht = 33 
    # Dois Pontos Convertidos
    h1 = 60
    pdf.image(f'{arquivo}/Pts_2_C.png', x=76, y=h1, w=wt, h=ht)
    # Valor dos Dois Pontos Convertidos
    pdf.set_xy(128, h1+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_2_C[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(128, h1+19)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_2_C[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Dois Pontos Tentados
    h2 = 96
    pdf.image(f'{arquivo}/Pts_2_T.png', x=76, y=h2, w=wt, h=ht)
    # Valor dos Dois Pontos Tentandos 
    pdf.set_xy(128, h2+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_2_T[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(128, h2+19)
    pdf.cell(w=8, h=7, txt= f'{valores.Pts_2_T[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Bolas Roubadas
    h3 = 134
    pdf.image(f'{arquivo}/BR.png', x=76, y=h3, w=wt, h=ht)
    # Valor das Bolas Roubadas
    pdf.set_xy(128, h3+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.BR[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(128, h3+19)
    pdf.cell(w=8, h=7, txt= f'{valores.BR[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Rebotes Defensivos
    h4 = 172
    pdf.image(f'{arquivo}/RD.png', x=76, y=h4, w=wt, h=ht)
    # Valor dos Rebotes Defensivos
    pdf.set_xy(128, h4+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.RD[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(128, h4+19)
    pdf.cell(w=8, h=7, txt= f'{valores.RD[1]}', border=1, ln=0, align='C')

# %%
def graficos_analise_avancadas_c3(pdf, valores, arquivo):
    pdf.set_text_color(0)
    wt = 57
    ht = 33 
    # Lances Livres Convertidos
    h1 = 60
    pdf.image(f'{arquivo}/LL_C.png', x=141, y=h1, w=wt, h=ht)
    # Valor dos Lances Livres Convertidos
    pdf.set_xy(192, h1+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.LL_C[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(192, h1+19)
    pdf.cell(w=8, h=7, txt= f'{valores.LL_C[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Lances Livres Tentados
    h2 = 96
    pdf.image(f'{arquivo}/LL_T.png', x=141, y=h2, w=wt, h=ht)
    # Valor dos Lances Livres Tentandos 
    pdf.set_xy(192, h2+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.LL_T[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(192, h2+19)
    pdf.cell(w=8, h=7, txt= f'{valores.LL_T[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Erros
    h3 = 134
    pdf.image(f'{arquivo}/ER.png', x=141, y=h3, w=wt, h=ht)
    # Valor dos Erros
    pdf.set_xy(192, h3+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.ER[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(192, h3+19)
    pdf.cell(w=8, h=7, txt= f'{valores.ER[1]}', border=1, ln=0, align='C')
    #######################################################################
    # Rebotes Totais
    h4 = 172
    pdf.image(f'{arquivo}/RT.png', x=141, y=h4, w=wt, h=ht)
    # Valor dos Rebotes Totais
    pdf.set_xy(192, h4+6)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=8, h=7, txt= f'{valores.RT[0]}', border=1, ln=0, align='C') 
    pdf.set_xy(192, h4+19)
    pdf.cell(w=8, h=7, txt= f'{valores.RT[1]}', border=1, ln=0, align='C')

# %%
def comentarios_p2_1(pdf):
    pdf.set_text_color(0)
    # Título
    pdf.set_xy(10, 210)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=70, h=10, txt= 'Considerações Finais', border=1, ln=1)
    # Comentários
    pdf.set_xy(10, 220)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(190, h=40, txt= '', border=1, ln=0, align='C')

# %% [markdown]
# # Terceira Página

# %%
def comentarios_p3(pdf, nome_casa):
    # Título
    pdf.set_xy(70, 20)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=70, h=10, txt= f'Descrição do Time {nome_casa}', border=1, ln=0, align='C')
    # Título do Comentário
    pdf.set_xy(10, 155)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=30, h=10, txt= 'Comentários', border=1)
    # Comentários
    pdf.set_xy(10, 165)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=35, txt= '', border=1, ln=0, align='C')

# %%
def melhores_jogadores_l1_casa_p3(pdf):
    # fotos dos jogadores
    pdf.set_xy(15, 40)
    pdf.cell(w=57, h=52, txt= '', border=1, ln=0, align='C')
    # Se for colocar a 5 posição o valor de h é 59
    # fotos dos jogadores
    pdf.set_xy(78, 40)
    pdf.cell(w=57, h=52, txt= '', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(141, 40)
    pdf.cell(w=57, h=52, txt= '', border=1, ln=0, align='C')

# %%
def foto_melhor_pontuador_p3(pdf, arquivo, jogador_1):
    # fotos dos jogadores
    pdf.image(f'{arquivo}/{jogador_1}.png', x=15, y=40, w=23, h=22)
    # Nome do jogador 
    pdf.set_xy(41, 42)
    pdf.set_font('Times', 'B', 14)
    pdf.multi_cell(w=23, h=6, txt= 'Pontos', border=1, align='C')

# %%
def cinco_melhores_pontuadores_p3(pdf, pontos_c_1):
    # Posição 1 
    pdf.set_xy(15, 64)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '1°', border=1, align='C')
    # Jogador 1
    pdf.set_xy(22, 64)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{pontos_c_1.Nome[0]}', border='B,R,T')
    # Valor 1 
    pdf.set_xy(45, 50)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=17, h=10, txt= f'{pontos_c_1.Pts_C[0]} Pts', border=1, align='C')
    # Posição 2
    pdf.set_xy(15, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '2°', border='R,B', align='C')   
    # Jogador 2
    pdf.set_xy(22, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{pontos_c_1.Nome[1]}', border='R,B')
    # Valor 2
    pdf.set_xy(59, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{pontos_c_1.Pts_C[1]} Pts', border='B,T', align='C')
    # Posição 3
    pdf.set_xy(15, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '3°', border='R,B', align='C')
    # Jogador 3
    pdf.set_xy(22, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{pontos_c_1.Nome[2]}', border='R,B')
    # Valor 3
    pdf.set_xy(59, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{pontos_c_1.Pts_C[2]} Pts', border='B,T', align='C')
    # Posição 4
    pdf.set_xy(15, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '4°', border='R', align='C')
    # Jogador 4
    pdf.set_xy(22, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{pontos_c_1.Nome[3]}', border='R')
    # Valor 3
    pdf.set_xy(59, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{pontos_c_1.Pts_C[3]} Pts', align='C')
    '''
    # Jogador 5
    pdf.set_xy(22, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{pontos_c_1.Nome[4]}', border='R')
    # Posição 5
    pdf.set_xy(15, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '5°', border='R', align='C')
    # Valor 3
    pdf.set_xy(59, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{pontos_c_1.Pts_C[4]} Pts', border='B,T', align='C')
    '''

# %%
def foto_melhor_pontuador_tres_p3(pdf, arquivo, jogador_2):
    # fotos dos jogadores
    pdf.image(f'{arquivo}/{jogador_2}.png', x=78, y=40, w=23, h=22)
    # Nome do jogador 
    pdf.set_xy(105, 42)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=28, h=6, txt= 'Três Pontos', border=1, align='C')

# %%
def cinco_melhores_pontuadores_tres_p3(pdf, tres_pontos_c_1):
    # Posição 1 
    pdf.set_xy(78, 64)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '1°', border=1, align='C')
    # Jogador 1
    pdf.set_xy(85, 64)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{tres_pontos_c_1.Nome[0]}', border='B,R,T')
    # Valor 1 
    pdf.set_xy(108, 50)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=17, h=10, txt= f'{tres_pontos_c_1.Pts_3_C[0]} Pts', border=1, align='C')
    # Posição 2
    pdf.set_xy(78, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '2°', border='R,B', align='C')   
    # Jogador 2
    pdf.set_xy(85, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{tres_pontos_c_1.Nome[1]}', border='R,B')
    # Valor 2
    pdf.set_xy(122, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{tres_pontos_c_1.Pts_3_C[1]} Pts', border='B,T', align='C')
    # Posição 3
    pdf.set_xy(78, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '3°', border='R,B', align='C')
    # Jogador 3
    pdf.set_xy(85, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{tres_pontos_c_1.Nome[2]}', border='R,B')
    # Valor 3
    pdf.set_xy(122, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{tres_pontos_c_1.Pts_3_C[2]} Pts', border='B,T', align='C')
    # Posição 4
    pdf.set_xy(78, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '4°', border='R', align='C')
    # Jogador 4
    pdf.set_xy(85, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{tres_pontos_c_1.Nome[3]}', border='R')
    # Valor 3
    pdf.set_xy(122, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{tres_pontos_c_1.Pts_3_C[3]} Pts', align='C')
    '''
    # Jogador 5
    pdf.set_xy(85, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{tres_pontos_c_1.Nome[4]}', border='R')
    # Posição 5
    pdf.set_xy(78, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '5°', border='R', align='C')
    # Valor 3
    pdf.set_xy(122, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{tres_pontos_c_1.Pts_3_C[4]} Pts', border='B,T', align='C')
    '''

# %%
def foto_melhor_pontuador_dois_p3(pdf, arquivo, jogador_3):
    # fotos dos jogadores
    pdf.image(f'{arquivo}/{jogador_3}.png', x=142, y=40, w=23, h=22)
    # Nome do jogador 
    pdf.set_xy(166, 42)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=28, h=6, txt= 'Dois Pontos', border=1, align='C')

# %%
def cinco_melhores_pontuadores_dois_p3(pdf, dois_pontos_c_1):
    # Posição 1 
    pdf.set_xy(141, 64)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '1°', border=1, align='C')
    # Jogador 1
    pdf.set_xy(148, 64)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{dois_pontos_c_1.Nome[0]}', border='B,R,T')
    # Valor 1 
    pdf.set_xy(172, 50)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=17, h=10, txt= f'{dois_pontos_c_1.Pts_2_C[0]} Pts', border=1, align='C')
    # Posição 2
    pdf.set_xy(141, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '2°', border='R,B', align='C')   
    # Jogador 2
    pdf.set_xy(148, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{dois_pontos_c_1.Nome[1]}', border='R,B')
    # Valor 2
    pdf.set_xy(185, 71)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{dois_pontos_c_1.Pts_2_C[1]} Pts', border='B,T', align='C')
    # Posição 3
    pdf.set_xy(141, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '3°', border='R,B', align='C')
    # Jogador 3
    pdf.set_xy(148, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{dois_pontos_c_1.Nome[2]}', border='R,B')
    # Valor 3
    pdf.set_xy(185, 78)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{dois_pontos_c_1.Pts_2_C[2]} Pts', border='B,T', align='C')
    # Posição 4
    pdf.set_xy(141, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '4°', border='R', align='C')
    # Jogador 4
    pdf.set_xy(148, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{dois_pontos_c_1.Nome[3]}', border='R')
    # Valor 3
    pdf.set_xy(185, 85)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{dois_pontos_c_1.Pts_2_C[3]} Pts', align='C')
    '''
    # Jogador 5
    pdf.set_xy(148, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{dois_pontos_c_1.Nome[4]}', border='R')
    # Posição 5
    pdf.set_xy(141, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '5°', border='R', align='C')
    # Valor 3
    pdf.set_xy(185, 92)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{dois_pontos_c_1.Pts_2_C[4]} Pts', border='B,T', align='C')
    '''

# %%
def melhores_jogadores_l2_casa_p3(pdf):
    # fotos dos jogadores
    pdf.set_xy(15, 98)
    pdf.cell(w=57, h=52, txt= '', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(78, 98)
    pdf.cell(w=57, h=52, txt= '', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(141, 98)
    pdf.cell(w=57, h=52, txt= '', border=1, ln=0, align='C')

# %%
def foto_melhor_assistente_p3(pdf, arquivo, jogador_4):
    # fotos dos jogadores
    pdf.image(f'{arquivo}/{jogador_4}.png', x=15, y=98, w=23, h=22)
    # Nome do jogador 
    pdf.set_xy(41, 100)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=26, h=6, txt= 'Assitência', border=1, align='C')

# %%
def cinco_melhores_assistencias_p3(pdf, as_1):
    # Posição 1 
    pdf.set_xy(15, 122)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '1°', border=1, align='C')
    # Jogador 1
    pdf.set_xy(22, 122)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{as_1.Nome[0]}', border='B,R,T')
    # Valor 1 
    pdf.set_xy(45, 108)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=17, h=10, txt= f'{as_1.AS[0]} AS', border=1, align='C')
    # Posição 2
    pdf.set_xy(15, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '2°', border='R,B', align='C')   
    # Jogador 2
    pdf.set_xy(22, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{as_1.Nome[1]}', border='R,B')
    # Valor 2
    pdf.set_xy(59, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{as_1.AS[1]} AS', border='B,T', align='C')
    # Posição 3
    pdf.set_xy(15, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '3°', border='R,B', align='C')
    # Jogador 3
    pdf.set_xy(22, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{as_1.Nome[2]}', border='R,B')
    # Valor 3
    pdf.set_xy(59, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{as_1.AS[2]} AS', border='B,T', align='C')
    # Posição 4
    pdf.set_xy(15, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '4°', border='R', align='C')
    # Jogador 4
    pdf.set_xy(22, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{as_1.Nome[3]}', border='R')
    # Valor 3
    pdf.set_xy(59, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{as_1.AS[3]} AS', align='C')
    '''
    # Jogador 5
    pdf.set_xy(22, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{as_1.Nome[4]}', border='R')
    # Posição 5
    pdf.set_xy(15, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '5°', border='R', align='C')
    # Valor 3
    pdf.set_xy(59, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{as_1.AS[4]} AS', border='B,T', align='C')
    '''

# %%
def foto_melhor_rebotes_p3(pdf, arquivo, jogador_5):
    # fotos dos jogadores
    pdf.image(f'{arquivo}/{jogador_5}.png', x=78, y=98, w=23, h=22)
    # Nome do jogador 
    pdf.set_xy(103, 100)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=32, h=6, txt= 'Rebotes Totais', border=1, align='C')

# %%
def cinco_melhores_reboteiros_p3(pdf, rt_1):
    # Posição 1 
    pdf.set_xy(78, 122)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '1°', border=1, align='C')
    # Jogador 1
    pdf.set_xy(85, 122)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{rt_1.Nome[0]}', border='B,R,T')
    # Valor 1 
    pdf.set_xy(108, 108)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=17, h=10, txt= f'{rt_1.RT[0]} RT', border=1, align='C')
    # Posição 2
    pdf.set_xy(78, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '2°', border='R,B', align='C')   
    # Jogador 2
    pdf.set_xy(85, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{rt_1.Nome[1]}', border='R,B')
    # Valor 2
    pdf.set_xy(122, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{rt_1.RT[1]} RT', border='B,T', align='C')
    # Posição 3
    pdf.set_xy(78, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '3°', border='R,B', align='C')
    # Jogador 3
    pdf.set_xy(85, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{rt_1.Nome[2]}', border='R,B')
    # Valor 3
    pdf.set_xy(122, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{rt_1.RT[2]} RT', border='B,T', align='C')
    # Posição 4
    pdf.set_xy(78, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '4°', border='R', align='C')
    # Jogador 4
    pdf.set_xy(85, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{rt_1.Nome[3]}', border='R')
    # Valor 3
    pdf.set_xy(122, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{rt_1.RT[3]} RT', align='C')
    '''
    # Jogador 5
    pdf.set_xy(85, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{rt_1.Nome[4]}', border='R')
    # Posição 5
    pdf.set_xy(78, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '5°', border='R', align='C')
    # Valor 3
    pdf.set_xy(122, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{rt_1.RT[4]} RT', border='B,T', align='C')
    '''

# %%
def foto_melhor_faltas_recebidas_p3(pdf, arquivo, jogador_6):
    # fotos dos jogadores
    pdf.image(f'{arquivo}/{jogador_6}.png', x=142, y=98, w=23, h=22)
    # Nome do jogador 
    pdf.set_xy(166, 99)
    pdf.set_font('Times', 'B', 14)
    pdf.multi_cell(w=28, h=5, txt= 'Faltas Recebidas', border=1, align='C')

# %%
def cinco_melhores_faltas_recebidas_p3(pdf, fr_1):
    # Posição 1 
    pdf.set_xy(141, 122)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '1°', border=1, align='C')
    # Jogador 1
    pdf.set_xy(148, 122)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{fr_1.Nome[0]}', border='B,R,T')
    # Valor 1 
    pdf.set_xy(172, 110)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=17, h=10, txt= f'{fr_1.FR[0]} FR', border=1, align='C')
    # Posição 2
    pdf.set_xy(141, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '2°', border='R,B', align='C')   
    # Jogador 2
    pdf.set_xy(148, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{fr_1.Nome[1]}', border='R,B')
    # Valor 2
    pdf.set_xy(185, 129)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{fr_1.FR[1]} FR', border='B,T', align='C')
    # Posição 3
    pdf.set_xy(141, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '3°', border='R,B', align='C')
    # Jogador 3
    pdf.set_xy(148, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{fr_1.Nome[2]}', border='R,B')
    # Valor 3
    pdf.set_xy(185, 136)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{fr_1.FR[2]} FR', border='B,T', align='C')
    # Posição 4
    pdf.set_xy(141, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '4°', border='R', align='C')
    # Jogador 4
    pdf.set_xy(148, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{fr_1.Nome[3]}', border='R')
    # Valor 3
    pdf.set_xy(185, 143)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{fr_1.FR[3]} FR', align='C')
    '''
    # Jogador 5
    pdf.set_xy(148, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.multi_cell(w=37, h=7, txt= f'{fr_1.Nome[4]}', border='R')
    # Posição 5
    pdf.set_xy(141, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=7, h=7, txt= '5°', border='R', align='C')
    # Valor 3
    pdf.set_xy(185, 150)
    pdf.set_font('Times', 'B', 11)
    pdf.cell(w=13, h=7, txt= f'{fr_1.FR[4]} FR', border='B,T', align='C')
    '''

# %%
def tabela_geral_casa_p3(pdf, arquivo):
    pdf.image(f'{arquivo}/teste5.png', x=15, y=210, w=180, h=70)

# %% [markdown]
# # Quarta Página

# %%
def comentarios_p4(pdf, nome_casa):
    # Título
    pdf.set_xy(60, 30)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=90, h=10, txt= f'Perídos Positivos do Time {nome_casa}', border=1, ln=0, align='C')
    # Título do Comentário
    pdf.set_xy(10, 110)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=30, h=10, txt= 'Comentários', border=1)
    # Comentários
    pdf.set_xy(10, 120)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=40, txt= '', border=1)

# %%
def grafico_periodos_positivos_casa(pdf, arquivo):
    pdf.image(f'{arquivo}/teste1.jpeg', x=0, y=45, w=200, h=60)

# %%
def grafico_tempo_posse_de_bola_casa(pdf, arquivo):
    pdf.image(f'{arquivo}/teste3.png', x=0, y=165, w=200, h=60)

# %%
def comentarios_p4_1(pdf):
    # Título do Comentário
    pdf.set_xy(10, 230)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=30, h=10, txt='Comentários', border=1)
    # Comentário
    pdf.set_xy(10, 240)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=30, txt= '', border=1)

# %% [markdown]
# # Quinta Página

# %%
def comentarios_p5(pdf, nome_casa):
    # Título 1
    pdf.set_xy(60, 30)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=90, h=10, txt= f'Melhores Quintetos do Time {nome_casa}', border=1, ln=0, align='C')

# %%
def primeiro_quinteto_fotos_casa(pdf): 
    # fotos dos jogadores
    pdf.set_xy(45, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(70, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(95, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(120, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(145, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Colocação
    pdf.set_xy(35, 50)
    pdf.set_font('Times', 'B', 18)
    pdf.cell(w=6, h=6, txt= '1°', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(10, 70)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=20, txt= 'Comentários', border=1, ln=0, align='C')

# %%
def segundo_quinteto_fotos_casa(pdf): 
    # fotos dos jogadores
    pdf.set_xy(45, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(70, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(95, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(120, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(145, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Colocação
    pdf.set_xy(35, 100)
    pdf.set_font('Times', 'B', 18)
    pdf.cell(w=6, h=6, txt= '2°', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(10, 120)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=20, txt= 'Comentários', border=1, ln=0, align='C')

# %%
def terceiro_quinteto_fotos_casa(pdf): 
    # fotos dos jogadores
    pdf.set_xy(45, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(70, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(95, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(120, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(145, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Colocação
    pdf.set_xy(35, 150)
    pdf.set_font('Times', 'B', 18)
    pdf.cell(w=6, h=6, txt= '3°', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(10, 170)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=20, txt= 'Comentários', border=1, ln=0, align='C')

# %%
def comentarios_p5_1(pdf):
    # Título
    pdf.set_xy(80, 195)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=50, h=10, txt= 'Melhores Substituições', border=1, ln=0, align='C')

# %%
def substituicao_1_casa(pdf):
    # fotos dos jogadores
    pdf.set_xy(20, 210)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(45, 210)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=60, h=30, txt= 'Comentários', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(110, 210)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(135, 210)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=60, h=30, txt= 'Comentários', border=1, ln=0, align='C')

# %%
def substituicao_2_casa(pdf):
    # fotos dos jogadores
    pdf.set_xy(20, 245)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(45, 245)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=60, h=30, txt= 'Comentários', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(110, 245)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(135, 245)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=60, h=30, txt= 'Comentários', border=1, ln=0, align='C')

# %% [markdown]
# # Sexta Página

# %%
def comentarios_p6(pdf, nome_fora):
    # Título
    pdf.set_xy(70, 20)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=70, h=10, txt= f'Descrição do Time {nome_fora}', border=1, ln=0, align='C')
    # Título do Comentário
    pdf.set_xy(10, 145)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=40, h=10, txt= 'Comentários', border=1, ln=0, align='C')
    # Comentários
    pdf.set_xy(10, 155)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=35, txt= '', border=1, ln=0, align='C')

# %%
def melhores_jogadores_l1_fora(pdf):
    wt = 30
    ht = 25     
    # fotos dos jogadores
    pdf.set_xy(20, 40)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=50, h=45, txt= 'Pontos Convertidos', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(80, 40)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=50, h=45, txt= 'Três Pontos', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(140, 40)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=50, h=45, txt= 'Dois Pontos', border=1, ln=0, align='C')

# %%
def melhores_jogadores_l2_fora(pdf):
    wt = 30
    ht = 25     
    # fotos dos jogadores
    pdf.set_xy(20, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=50, h=45, txt= 'Assistências', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(80, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=50, h=45, txt= 'Rebotes Totais', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(140, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=50, h=45, txt= 'Faltas Recebidas', border=1, ln=0, align='C')

# %%
def tabela_geral_fora(pdf, arquivo):
    pdf.image(f'{arquivo}/teste6.png', x=15, y=200, w=180, h=70)

# %% [markdown]
# # Setima Página

# %%
def comentarios_p7(pdf, nome_fora):
    # Título
    pdf.set_xy(60, 30)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=90, h=10, txt= f'Perídos Positivos do Time {nome_fora}', border=1, ln=0, align='C')
    # Título do Comentário
    pdf.set_xy(10, 110)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=30, h=10, txt= 'Comentários', border=1)
    # Comentários
    pdf.set_xy(10, 120)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=40, txt= '', border=1)

# %%
def grafico_periodos_positivos_fora(pdf, arquivo):
    pdf.image(f'{arquivo}/teste2.jpeg', x=0, y=45, w=200, h=60)

# %%
def grafico_tempo_posse_de_bola_fora(pdf, arquivo):
    pdf.image(f'{arquivo}/teste4.png', x=0, y=165, w=200, h=60)

# %%
def comentarios_p7_1(pdf):
    # Título do Comentário
    pdf.set_xy(10, 230)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=30, h=10, txt='Comentários', border=1)
    # Comentário
    pdf.set_xy(10, 240)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=30, txt= '', border=1)

# %% [markdown]
# # Oitava Página

# %%
def comentarios_p8(pdf, nome_fora):
    # Título 1
    pdf.set_xy(60, 30)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=90, h=10, txt= f'Melhores Quintetos do Time {nome_fora}', border=1, ln=0, align='C')

# %%
def primeiro_quinteto_fotos_fora(pdf): 
    # fotos dos jogadores
    pdf.set_xy(45, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(70, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(95, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(120, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(145, 45)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Colocação
    pdf.set_xy(35, 50)
    pdf.set_font('Times', 'B', 18)
    pdf.cell(w=6, h=6, txt= '1°', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(10, 70)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=20, txt= 'Comentários', border=1, ln=0, align='C')

# %%
def segundo_quinteto_fotos_fora(pdf): 
    # fotos dos jogadores
    pdf.set_xy(45, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(70, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(95, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(120, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(145, 95)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Colocação
    pdf.set_xy(35, 100)
    pdf.set_font('Times', 'B', 18)
    pdf.cell(w=6, h=6, txt= '2°', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(10, 120)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=20, txt= 'Comentários', border=1, ln=0, align='C')

# %%
def terceiro_quinteto_fotos_fora(pdf): 
    # fotos dos jogadores
    pdf.set_xy(45, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(70, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(95, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(120, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(145, 145)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Colocação
    pdf.set_xy(35, 150)
    pdf.set_font('Times', 'B', 18)
    pdf.cell(w=6, h=6, txt= '3°', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(10, 170)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=190, h=20, txt= 'Comentários', border=1, ln=0, align='C')

# %%
def comentarios_p8_1(pdf):
    # Título
    pdf.set_xy(80, 195)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=50, h=10, txt= 'Melhores Substituições', border=1, ln=0, align='C')

# %%
def substituicao_1_fora(pdf):
    # fotos dos jogadores
    pdf.set_xy(20, 210)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(45, 210)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=60, h=30, txt= 'Comentários', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(110, 210)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(135, 210)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=60, h=30, txt= 'Comentários', border=1, ln=0, align='C')

# %%
def substituicao_2_fora(pdf):
    # fotos dos jogadores
    pdf.set_xy(20, 245)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(45, 245)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=60, h=30, txt= 'Comentários', border=1, ln=0, align='C')
    # fotos dos jogadores
    pdf.set_xy(110, 245)
    pdf.set_font('Times', 'B', 14)
    pdf.cell(w=20, h=20, txt= 'Foto', border=1, ln=0, align='C')
    # Comentários 
    pdf.set_xy(135, 245)
    pdf.set_font('Times', 'B', 12)
    pdf.cell(w=60, h=30, txt= 'Comentários', border=1, ln=0, align='C')
